# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wbgapi as wb
from sklearn.manifold import TSNE

# %%
wb.topic.info()
# Out:
# id    value
# ----  -------------------------------
# 1     Agriculture & Rural Development
# 2     Aid Effectiveness
# 3     Economy & Growth
# 4     Education
# 5     Energy & Mining
# 6     Environment
# 7     Financial Sector
# 8     Health
# 9     Infrastructure
# 10    Social Protection & Labor
# 11    Poverty
# 12    Private Sector
# 13    Public Sector
# 14    Science & Technology
# 15    Social Development
# 16    Urban Development
# 17    Gender
# 18    Millenium development goals
# 19    Climate Change
# 20    External Debt
# 21    Trade
#       21 elements

# %%
wb.series.info(topic=8)
# Out:
# id                 value
# -----------------  -------------------------------------------------------------------------------------------------------------------------------
# SP.POP.DPND.OL     Age dependency ratio, old (% of working-age population)
# SP.POP.DPND.YG     Age dependency ratio, young (% of working-age population)
# SH.HIV.ARTC.ZS     Antiretroviral therapy coverage (% of people living with HIV)
# SH.HIV.PMTC.ZS     Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)
# SH.MLR.TRET.ZS     Children with fever receiving antimalarial drugs (% of children under age 5 with fever)
# SH.CON.1524.FE.ZS  Condom use, population ages 15-24, female (% of females ages 15-24)
# SH.XPD.CHEX.PC.CD  Current health expenditure per capita (current US$)
# SH.XPD.CHEX.PP.CD  Current health expenditure per capita, PPP (current international $)
# SH.STA.ORTH        Diarrhea treatment (% of children under 5 who received ORS packet)
# ...

# %%
wb.region.info()
# Out:
# code    name
# ------  -----------------------------------------------------
# AFE     Africa Eastern and Southern
# AFR     Africa
# AFW     Africa Western and Central
# ARB     Arab World
# CAA     Sub-Saharan Africa (IFC classification)
# CEA     East Asia and the Pacific (IFC classification)
# CEB     Central Europe and the Baltics
# CEU     Europe and Central Asia (IFC classification)
# CLA     Latin America and the Caribbean (IFC classification)
# CME     Middle East and North Africa (IFC classification)
# CSA     South Asia (IFC classification)
# CSS     Caribbean small states
# EAP     East Asia & Pacific (excluding high income)
# EAR     Early-demographic dividend
# EAS     East Asia & Pacific
# ECA     Europe & Central Asia (excluding high income)
# ECS     Europe & Central Asia
# EMU     Euro area
# EUU     European Union
# FCS     Fragile and conflict affected situations
# HPC     Heavily indebted poor countries (HIPC)
# ...

# %%
df = wb.data.DataFrame('SP.URB.TOTL.IN.ZS', wb.region.members('EUU'), time=range(1990,2021), skipBlanks=True)

# %%
df
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# AUT      62.960  62.689  62.417  62.144  61.870  61.596  61.320  61.045
# BEL      96.377  96.461  96.542  96.622  96.700  96.777  96.851  96.924
# BGR      66.377  66.717  67.056  67.330  67.557  67.782  68.007  68.231
# CYP      66.776  67.188  67.598  67.792  67.915  68.038  68.161  68.283
# CZE      75.220  75.158  75.030  74.901  74.772  74.643  74.513  74.382
# DEU      73.118  73.269  73.360  73.497  73.710  73.922  74.133  74.342
# DNK      84.843  84.871  84.898  84.925  84.952  84.979  85.006  85.033
# ESP      75.351  75.528  75.610  75.692  75.774  75.856  75.938  76.019
# EST      71.231  71.046  70.860  70.674  70.487  70.300  70.111  69.923
# FIN      79.367  79.843  80.128  80.409  80.688  80.963  81.223  81.466
# FRA      74.056  74.229  74.401  74.572  74.743  74.912  75.082  75.250
# GRC      71.467  71.635  71.757  71.878  71.998  72.119  72.239  72.358
# ...

# %%
socjo_demogra_europe = ['SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SM.POP.NETM', 'SP.POP.0014.TO.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.TOTL.FE.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SP.URB.TOTL.IN.ZS', 'SL.UEM.TOTL.ZS', 'SP.URB.TOTL', 'EN.URB.MCTY.TL.ZS', 'SE.ENR.PRSC.FM.ZS', 'SP.URB.TOTL.IN.ZS',  'SP.URB.TOTL.IN.ZS']

# %%
economic_europe = ['GC.XPN.TOTL.GD.ZS', 'BX.KLT.DINV.CD.WD', 'NY.GDP.MKTP.KD.ZG', 'NY.GDP.PCAP.KD.ZG', 'NY.GNP.PCAP.CD', 'NY.GNP.ATLS.CD', 'BX.GRT.EXTA.CD.WD', 'NY.GNS.ICTR.ZS', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'BX.TRF.PWKR.CD.DT', 'GC.REV.XGRT.GD.ZS', 'BX.GRT.TECH.CD.WD', 'FI.RES.TOTL.CD', 'NV.AGR.TOTL.ZS', 'NE.EXP.GNFS.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.PP.CD', 'NY.GNP.PCAP.PP.CD', 'NY.GNP.MKTP.PP.CD', 'NE.GDI.TOTL.ZS', 'NE.IMP.GNFS.ZS', 'NY.GDP.DEFL.KD.ZG', 'NV.MNF.TECH.ZS.UN', 'PA.NUS.PPP', 'PA.NUS.PPPC.RF', ]

# %%
health_indicators_europe = ['SP.ADO.TFRT', 'SP.ADO.TFRT', 'SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SH.IMM.IDPT', 'SH.TBS.INCD', 'SP.DYN.LE00.FE.IN', 'SP.DYN.LE00.IN', 'SH.STA.TRAF.P5', 'SP.DYN.LE00.MA.IN', 'SH.IMM.MEAS', 'SH.MED.BEDS.ZS', 'SP.POP.DPND', 'SH.SGR.IRSK.ZS', 'SN.ITK.DEFC.ZS', 'SH.ANM.CHLD.ZS', 'SH.HIV.1524.MA.ZS', 'SH.HIV.1524.MA.ZS', 'SP.POP.TOTL.FE.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.0014.TO.ZS', 'SM.POP.NETM', 'SH.DYN.NMRT', 'SH.STA.MMRT', 'SP.DYN.IMRT.IN', 'SH.DYN.MORT', 'SP.POP.1564.TO.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SH.HIV.1524.FE.ZS', 'SH.DYN.AIDS.ZS', 'SH.STA.OWGH.ZS', 'SM.POP.REFG', 'SH.SGR.CRSK.ZS', ]

# %%
wb.region.members('AFR')
# Out:
# code    name
# ------  -----------------------------------------------------
# AFE     Africa Eastern and Southern
# AFR     Africa
# AFW     Africa Western and Central
# ARB     Arab World
# CAA     Sub-Saharan Africa (IFC classification)
# CEA     East Asia and the Pacific (IFC classification)
# CEB     Central Europe and the Baltics
# CEU     Europe and Central Asia (IFC classification)
# CLA     Latin America and the Caribbean (IFC classification)
# CME     Middle East and North Africa (IFC classification)
# CSA     South Asia (IFC classification)
# CSS     Caribbean small states
# EAP     East Asia & Pacific (excluding high income)
# EAR     Early-demographic dividend
# EAS     East Asia & Pacific
# ECA     Europe & Central Asia (excluding high income)
# ECS     Europe & Central Asia
# EMU     Euro area
# EUU     European Union
# FCS     Fragile and conflict affected situations
# HPC     Heavily indebted poor countries (HIPC)
# ...

# %%
wb.economy.info('CHN')
# Out:
# id    value       region    incomeLevel
# ----  ----------  --------  -------------
# CHN   China       EAS       UMC
#       1 elements

# %%
l = ['CHN', 'USA', 'CAN', 'JPN', 'BRA', 'IND']

# %%
df = wb.data.DataFrame(health_indicators_europe, l, time=range(1990,2021), skipBlanks=True)

# %%
df
# Out:
#                                  YR1990        YR1991        YR1992  \
# economy series
# BRA     SH.ANM.CHLD.ZS              NaN           NaN           NaN
#         SH.DYN.AIDS.ZS     2.000000e-01  2.000000e-01  2.000000e-01
#         SH.DYN.MORT        6.320000e+01  6.040000e+01  5.740000e+01
#         SH.DYN.NMRT        2.610000e+01  2.530000e+01  2.450000e+01
#         SH.IMM.IDPT        6.600000e+01  7.800000e+01  7.100000e+01
# ...                                 ...           ...           ...
# USA     SP.POP.65UP.TO.ZS  1.228448e+01  1.232691e+01  1.239685e+01
#         SP.POP.DPND        5.115130e+01  5.153986e+01  5.194994e+01
#         SP.POP.GROW        1.129651e+00  1.336261e+00  1.386886e+00
#         SP.POP.TOTL        2.496230e+08  2.529810e+08  2.565140e+08
#         SP.POP.TOTL.FE.ZS  5.104417e+01  5.101374e+01  5.098214e+01
#
#                                  YR1993        YR1994        YR1995  \
# economy series
# ...

# %%
health_indicators_2 = ['SP.ADO.TFRT', 'SP.ADO.TFRT', 'SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SH.IMM.IDPT', 'SP.DYN.LE00.FE.IN', 'SP.DYN.LE00.IN', 'SP.DYN.LE00.MA.IN', 'SH.IMM.MEAS', 'SP.POP.DPND', 'SP.POP.TOTL.FE.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.0014.TO.ZS', 'SM.POP.NETM', 'SH.DYN.NMRT', 'SP.DYN.IMRT.IN', 'SH.DYN.MORT', 'SP.POP.1564.TO.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SM.POP.REFG']

# %%
df = wb.data.DataFrame(health_indicators_2, l, time=range(1990, 2021), skipBlanks=True)
df
# Out:
#                                  YR1990        YR1991        YR1992  \
# economy series
# BRA     SH.DYN.MORT        6.320000e+01  6.040000e+01  5.740000e+01
#         SH.DYN.NMRT        2.610000e+01  2.530000e+01  2.450000e+01
#         SH.IMM.IDPT        6.600000e+01  7.800000e+01  7.100000e+01
#         SH.IMM.MEAS        7.800000e+01  8.500000e+01  9.100000e+01
#         SM.POP.NETM        6.457000e+03 -3.065900e+04 -2.027000e+04
# ...                                 ...           ...           ...
# USA     SP.POP.65UP.TO.ZS  1.228448e+01  1.232691e+01  1.239685e+01
#         SP.POP.DPND        5.115130e+01  5.153986e+01  5.194994e+01
#         SP.POP.GROW        1.129651e+00  1.336261e+00  1.386886e+00
#         SP.POP.TOTL        2.496230e+08  2.529810e+08  2.565140e+08
#         SP.POP.TOTL.FE.ZS  5.104417e+01  5.101374e+01  5.098214e+01
#
#                                  YR1993        YR1994        YR1995  \
# economy series
# ...

# %%
economic_indicators_2 = ['BX.KLT.DINV.CD.WD', 'BX.GRT.EXTA.CD.WD', 'NY.GNS.ICTR.ZS', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'BX.TRF.PWKR.CD.DT', 'BX.GRT.TECH.CD.WD', 'FI.RES.TOTL.CD', 'NV.AGR.TOTL.ZS', 'NE.EXP.GNFS.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.PP.CD', 'NY.GNP.PCAP.PP.CD', 'NY.GNP.MKTP.PP.CD', 'NE.GDI.TOTL.ZS', 'NE.IMP.GNFS.ZS', 'NV.MNF.TECH.ZS.UN', 'PA.NUS.PPP', 'PA.NUS.PPPC.RF']

# %%
df = wb.data.DataFrame(economic_indicators_2, l, time=range(1990, 2021), skipBlanks=True)
df
# Out:
#                                  YR1990        YR1991        YR1992  \
# economy series
# BRA     BX.GRT.EXTA.CD.WD  4.066000e+07  4.869000e+07  6.024000e+07
#         BX.GRT.TECH.CD.WD  1.408500e+08  1.578800e+08  1.753200e+08
#         BX.KLT.DINV.CD.WD  9.890000e+08  1.103000e+09  2.061000e+09
#         BX.TRF.PWKR.CD.DT  5.730000e+08  1.110000e+09  1.791000e+09
#         FI.RES.TOTL.CD     9.997591e+09  9.391632e+09  2.375065e+10
# ...                                 ...           ...           ...
# USA     NY.GNP.MKTP.PP.CD  5.902290e+12  6.096750e+12  6.435469e+12
#         NY.GNP.PCAP.PP.CD  2.364000e+04  2.410000e+04  2.509000e+04
#         NY.GNS.ICTR.ZS     1.875605e+01  1.881002e+01  1.768152e+01
#         PA.NUS.PPP         1.000000e+00  1.000000e+00  1.000000e+00
#         PA.NUS.PPPC.RF     1.000000e+00  1.000000e+00  1.000000e+00
#
#                                  YR1993        YR1994        YR1995  \
# economy series
# ...

# %%
socjo_demogra_indicators_2 = ['SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SM.POP.NETM', 'SP.POP.0014.TO.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.TOTL.FE.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SP.URB.TOTL.IN.ZS', 'SL.UEM.TOTL.ZS', 'SP.URB.TOTL', 'EN.URB.MCTY.TL.ZS', 'SP.URB.TOTL.IN.ZS',  'SP.URB.TOTL.IN.ZS']

# %%
df = wb.data.DataFrame(socjo_demogra_indicators_2, l, time=range(1990, 2021))
df
# Out:
#                                  YR1990        YR1991        YR1992  \
# economy series
# BRA     EN.URB.MCTY.TL.ZS  3.563361e+01  3.596896e+01  3.619030e+01
#         SL.UEM.TOTL.ZS              NaN  6.366000e+00  6.420000e+00
#         SM.POP.NETM        6.457000e+03 -3.065900e+04 -2.027000e+04
#         SP.DYN.CDRT.IN     7.158000e+00  7.068000e+00  6.951000e+00
#         SP.DYN.TFRT.IN     2.905000e+00  2.815000e+00  2.719000e+00
# ...                                 ...           ...           ...
# USA     SP.POP.GROW        1.129651e+00  1.336261e+00  1.386886e+00
#         SP.POP.TOTL        2.496230e+08  2.529810e+08  2.565140e+08
#         SP.POP.TOTL.FE.ZS  5.104417e+01  5.101374e+01  5.098214e+01
#         SP.URB.TOTL        1.879661e+08  1.915091e+08  1.951995e+08
#         SP.URB.TOTL.IN.ZS  7.530000e+01  7.570100e+01  7.609700e+01
#
#                                  YR1993        YR1994        YR1995  \
# economy series
# ...

# %%
df = wb.data.DataFrame(socjo_demogra_indicators_2, 'all', time=range(1996, 2022))
df
# Out:
#                                  YR1996        YR1997        YR1998  \
# economy series
# ABW     EN.URB.MCTY.TL.ZS           NaN           NaN           NaN
#         SL.UEM.TOTL.ZS              NaN           NaN           NaN
#         SM.POP.NETM        1.636000e+03  1.656000e+03  1.786000e+03
#         SP.DYN.CDRT.IN     6.338000e+00  6.359000e+00  6.339000e+00
#         SP.DYN.TFRT.IN     2.153000e+00  2.144000e+00  1.957000e+00
# ...                                 ...           ...           ...
# ZWE     SP.POP.GROW        1.660946e+00  1.634689e+00  1.623404e+00
#         SP.POP.TOTL        1.117817e+07  1.136240e+07  1.154836e+07
#         SP.POP.TOTL.FE.ZS  5.243785e+01  5.243603e+01  5.243748e+01
#         SP.URB.TOTL        3.591770e+06  3.696644e+06  3.803916e+06
#         SP.URB.TOTL.IN.ZS  3.213200e+01  3.253400e+01  3.293900e+01
#
#                                  YR1999        YR2000        YR2001  \
# economy series
# ...

# %%
indicator_to_delate_economic = []
threshold = len(df.columns) * 0.80
for indicator in economic_indicators_2:
    print(indicator)
    df = wb.data.DataFrame(indicator, economy='all', time=range(1996,2021))
    df1 = df.dropna(thresh=threshold)
    to_delate = set(df.index.astype(str)) - set(df1.index.astype(str))
    print(to_delate)
    print(len(to_delate))
    if len(to_delate) > 100:
        indicator_to_delate_economic.append(indicator)
# Out:
# BX.KLT.DINV.CD.WD
# {'MNE', 'GIB', 'PLW', 'NRU', 'FSM', 'XKX', 'AND', 'SXM', 'NCL', 'GEO', 'SYR', 'BTN', 'MNP', 'CUB', 'SMR', 'MCO', 'VIR', 'LIE', 'TLS', 'IRQ', 'TCA', 'CHI', 'GUM', 'BIH', 'GRL', 'INX', 'BMU', 'ASM', 'SRB', 'TUV', 'MHL', 'PRI', 'CUW', 'SLV', 'FRO', 'LUX', 'YEM', 'SSD', 'IMN', 'MAF'}
# 40
# BX.GRT.EXTA.CD.WD
# ...

# %%
indicator_to_delate_economic
# Out:
# ['BX.GRT.EXTA.CD.WD',
#  'NY.GNS.ICTR.ZS',
#  'BX.GRT.TECH.CD.WD',
#  'FI.RES.TOTL.CD',
#  'NV.MNF.TECH.ZS.UN']

# %%
economic_indicators_3 = ['BX.KLT.DINV.CD.WD', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'BX.TRF.PWKR.CD.DT', 'NV.AGR.TOTL.ZS', 'NE.EXP.GNFS.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.PP.CD', 'NY.GNP.PCAP.PP.CD', 'NY.GNP.MKTP.PP.CD', 'NE.GDI.TOTL.ZS', 'NE.IMP.GNFS.ZS', 'PA.NUS.PPP', 'PA.NUS.PPPC.RF']

# %%
df = wb.data.DataFrame(economic_indicators_3, 'all', time=range(1996, 2022))
df
# Out:
#                                  YR1996        YR1997        YR1998  \
# economy series
# ABW     BX.KLT.DINV.CD.WD  8.502793e+07  1.978212e+08  1.134637e+08
#         BX.TRF.PWKR.CD.DT  1.620112e+06  1.843575e+06  1.620112e+06
#         FP.CPI.TOTL.ZG     3.225288e+00  2.999948e+00  1.869489e+00
#         NE.EXP.GNFS.ZS     8.663968e+01  8.253100e+01  7.963771e+01
#         NE.GDI.TOTL.ZS     2.846154e+01  3.023341e+01  3.170077e+01
# ...                                 ...           ...           ...
# ZWE     NY.GDP.PCAP.PP.CD  2.185929e+03  2.246209e+03  2.299395e+03
#         NY.GNP.MKTP.PP.CD  2.068948e+10  2.054208e+10  1.999152e+10
#         NY.GNP.PCAP.PP.CD  1.850000e+03  1.810000e+03  1.730000e+03
#         PA.NUS.PPP         5.486339e-01  5.238058e-01  3.778704e-01
#         PA.NUS.PPPC.RF     5.486339e-01  5.238058e-01  3.778704e-01
#
#                                  YR1999        YR2000        YR2001  \
# economy series
# ...

# %%
indicator_to_delate_economic = []
threshold = len(df.columns) * 0.8
for indicator in economic_indicators_3:
    print(indicator)
    df = wb.data.DataFrame(indicator, economy='all', time=range(1996,2021))
    df1 = df.dropna(thresh=threshold)
    to_delate = set(df.index.astype(str)) - set(df1.index.astype(str))
    print(to_delate)
    print(len(to_delate))
    if len(to_delate) > 100:
        indicator_to_delate_economic.append(indicator)
# Out:
# BX.KLT.DINV.CD.WD
# {'MNE', 'GIB', 'NRU', 'FSM', 'XKX', 'AND', 'SXM', 'SYR', 'MNP', 'CUB', 'SMR', 'MCO', 'VIR', 'LIE', 'TLS', 'TCA', 'CHI', 'GUM', 'GRL', 'INX', 'ASM', 'SRB', 'TUV', 'PRI', 'CUW', 'FRO', 'LUX', 'SSD', 'IMN', 'MAF'}
# 30
# NV.IND.TOTL.ZS
# {'ERI', 'GIB', 'VEN', 'DJI', 'NRU', 'SLB', 'XKX', 'MDG', 'GNQ', 'MMR', 'PYF', 'LCA', 'SXM', 'QAT', 'OSS', 'KWT', 'MNP', 'VGB', 'SMR', 'MCO', 'ARM', 'LIE', 'VIR', 'CHI', 'GUM', 'SOM', 'SST', 'MDV', 'GRL', 'INX', 'ASM', 'CAF', 'TUV', 'AFG', 'FCS', 'BHR', 'LBY', 'PRK', 'STP', 'SSD', 'IMN', 'MAF', 'CYM'}
# 43
# FP.CPI.TOTL.ZG
# {'MNE', 'TJK', 'GIB', 'ERI', 'PLW', 'KIR', 'VEN', 'DJI', 'SLE', 'NRU', 'XKX', 'AND', 'PYF', 'TKM', 'SXM', 'NCL', 'ARE', 'SYR', 'MNP', 'GIN', 'VGB', 'CUB', 'SMR', 'UZB', 'ARG', 'MCO', 'VIR', 'LIE', 'TLS', 'TCA', 'BIH', 'CHI', 'GUM', 'SOM', 'COM', 'GRL', 'INX', 'BMU', 'ASM', 'LBN', 'MOZ', 'MHL', 'AFG', 'TUV', 'OMN', 'PRI', 'LBY', 'CUW', 'ZWE', 'PRK', 'FRO', 'NAM', 'YEM', 'SSD', 'LBR', 'IMN', 'MAF', 'CYM'}
# 58
# ...

# %%
all = {'MNA', 'CHN', 'TJK', 'VEN', 'FSM', 'GRC', 'USA', 'NER', 'PYF', 'AFE', 'SGP', 'TSA', 'GIN', 'UZB', 'ARG', 'LIE', 'CHI', 'COL', 'AUT', 'DMA', 'BEN', 'ECA', 'ATG', 'AFG', 'UGA', 'WSM', 'AGO', 'SLV', 'PAN', 'UMC', 'IDX', 'PLW', 'SYC', 'PSS', 'KGZ', 'MMR', 'BLR', 'ISR', 'VNM', 'MEX', 'BGD', 'OSS', 'MCO', 'HKG', 'IRQ', 'GRL', 'CAF', 'LBN', 'SWZ', 'LVA', 'LBY', 'PAK', 'LMY', 'CHE', 'CYM', 'LKA', 'SSA', 'KOR', 'BRA', 'CSS', 'MUS', 'ARB', 'CEB', 'IND', 'BTN', 'NAC', 'SUR', 'DOM', 'ESP', 'SST', 'MOZ', 'TUV', 'FCS', 'TMN', 'BRN', 'ETH', 'ZWE', 'THA', 'TON', 'MRT', 'CMR', 'YEM', 'LBR', 'SSF', 'MAF', 'DJI', 'AUS', 'CHL', 'JPN', 'EAP', 'SAU', 'MNG', 'AND', 'FRA', 'NCL', 'SYR', 'BEL', 'NIC', 'VGB', 'NOR', 'EMU', 'TGO', 'BOL', 'VCT', 'OMN', 'SVN', 'BHR', 'LTU', 'NZL', 'PRK', 'IRL', 'TCD', 'GRD', 'NAM', 'DEU', 'SOM', 'MNE', 'GIB', 'ZMB', 'EAS', 'JAM', 'KHM', 'PST', 'SXM', 'UKR', 'MAR', 'TZA', 'COD', 'VUT', 'KNA', 'PSE', 'WLD', 'CUB', 'GMB', 'GTM', 'RWA', 'URY', 'TLA', 'INX', 'BMU', 'ASM', 'SVK', 'BDI', 'NLD', 'BFA', 'GUY', 'CUW', 'MEA', 'LUX', 'STP', 'PRY', 'HTI', 'HND', 'NPL', 'IMN', 'JOR', 'LSO', 'AZE', 'IBT', 'RUS', 'GNB', 'LDC', 'MIC', 'LCA', 'DNK', 'LMC', 'ZAF', 'QAT', 'EAR', 'FJI', 'ARM', 'TCA', 'CPV', 'GUM', 'LIC', 'SEN', 'BLZ', 'AFW', 'MDV', 'ITA', 'PRT', 'CYP', 'MHL', 'SRB', 'IBD', 'KAZ', 'MLT', 'EUU', 'HRV', 'KEN', 'LAC', 'IDN', 'OED', 'BRB', 'LAO', 'ERI', 'DZA', 'GHA', 'SLE', 'TUN', 'XKX', 'MDG', 'TKM', 'GAB', 'PHL', 'SDN', 'COG', 'HPC', 'GEO', 'CZE', 'IDA', 'TSS', 'ABW', 'GBR', 'CIV', 'VIR', 'TLS', 'BWA', 'CAN', 'PNG', 'HUN', 'PER', 'SWE', 'PRI', 'ISL', 'MLI', 'ARE', 'EGY', 'IDB', 'KIR', 'NRU', 'SLB', 'ALB', 'HIC', 'MYS', 'GNQ', 'POL', 'NGA', 'MAC', 'ROU', 'KWT', 'MNP', 'BHS', 'LTE', 'BGR', 'ECS', 'TTO', 'PRE', 'FIN', 'SMR', 'MWI', 'IRN', 'BIH', 'MKD', 'COM', 'TEC', 'TUR', 'SAS', 'TEA', 'CRI', 'LCN', 'FRO', 'EST', 'MDA', 'SSD', 'ECU'}

# %%
to_delate_countrys = {'MNA', 'GIB', 'VEN', 'EAS', 'PYF', 'AFE', 'PST', 'SXM', 'TSA', 'WLD', 'CUB', 'LIE', 'CHI', 'ECA', 'TLA', 'INX', 'ASM', 'AFG', 'CUW', 'MEA', 'STP', 'UMC', 'IMN', 'IDX', 'IBT', 'PSS', 'LDC', 'MIC', 'LMC', 'EAR', 'OSS', 'MCO', 'TCA', 'GUM', 'LIC', 'AFW', 'GRL', 'IBD', 'EUU', 'LAC', 'LMY', 'OED', 'CYM', 'SSA', 'XKX', 'CSS', 'ARB', 'CEB', 'HPC', 'IDA', 'TSS', 'NAC', 'VIR', 'SST', 'FCS', 'TMN', 'YEM', 'SSF', 'MAF', 'IDB', 'DJI', 'NRU', 'HIC', 'EAP', 'AND', 'NCL', 'SYR', 'MNP', 'LTE', 'VGB', 'ECS', 'PRE', 'EMU', 'TEC', 'SAS', 'TEA', 'PRK', 'LCN', 'FRO', 'SSD', 'SOM'}

# %%
countrys = all - to_delate_countrys

# %%
df = wb.data.DataFrame(economic_indicators_3, all, time=range(1996, 2022))

# %%
df
# Out:
#                                  YR1996        YR1997        YR1998  \
# economy series
# ABW     BX.KLT.DINV.CD.WD  8.502793e+07  1.978212e+08  1.134637e+08
#         BX.TRF.PWKR.CD.DT  1.620112e+06  1.843575e+06  1.620112e+06
#         FP.CPI.TOTL.ZG     3.225288e+00  2.999948e+00  1.869489e+00
#         NE.EXP.GNFS.ZS     8.663968e+01  8.253100e+01  7.963771e+01
#         NE.GDI.TOTL.ZS     2.846154e+01  3.023341e+01  3.170077e+01
# ...                                 ...           ...           ...
# ZWE     NY.GDP.PCAP.PP.CD  2.185929e+03  2.246209e+03  2.299395e+03
#         NY.GNP.MKTP.PP.CD  2.068948e+10  2.054208e+10  1.999152e+10
#         NY.GNP.PCAP.PP.CD  1.850000e+03  1.810000e+03  1.730000e+03
#         PA.NUS.PPP         5.486339e-01  5.238058e-01  3.778704e-01
#         PA.NUS.PPPC.RF     5.486339e-01  5.238058e-01  3.778704e-01
#
#                                  YR1999        YR2000        YR2001  \
# economy series
# ...

# %%
economic_indicators_3 = ['BX.KLT.DINV.CD.WD', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'BX.TRF.PWKR.CD.DT', 'NV.AGR.TOTL.ZS', 'NE.EXP.GNFS.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.PP.CD', 'NY.GNP.PCAP.PP.CD', 'NY.GNP.MKTP.PP.CD', 'NE.GDI.TOTL.ZS', 'NE.IMP.GNFS.ZS', 'PA.NUS.PPP', 'PA.NUS.PPPC.RF']

# %%
df = wb.data.DataFrame('BX.KLT.DINV.CD.WD', all, time=range(1996, 2022))

# %%
df
# Out:
#                YR1996        YR1997        YR1998        YR1999        YR2000  \
# economy
# ABW      8.502793e+07  1.978212e+08  1.134637e+08  4.675419e+08 -1.279330e+08
# AFE      2.087427e+09  5.757028e+09  4.121574e+09  6.254804e+09  4.315007e+09
# AFG      6.900000e+05 -1.460000e+06 -1.000000e+04  6.040000e+06  1.700000e+05
# AFW      1.182474e+09  1.622432e+09  1.897977e+09  2.391058e+09  2.560095e+09
# AGO      1.805590e+08  4.116600e+08  1.113970e+09  2.471460e+09  8.786200e+08
# ...               ...           ...           ...           ...           ...
# XKX               NaN           NaN           NaN           NaN           NaN
# YEM     -6.010000e+07 -1.385000e+08 -2.194000e+08 -3.076000e+08  6.399510e+06
# ZAF      8.163893e+08  3.810544e+09  5.503386e+08  1.503332e+09  9.688314e+08
# ZMB      1.271000e+08  2.074000e+08  1.980000e+08  1.620000e+08  1.217000e+08
# ZWE      8.090000e+07  1.351000e+08  4.443000e+08  5.900000e+07  2.320000e+07
#
# ...

# %%
to_delate = {'AND', 'ASM', 'BIH', 'BTN', 'CHI', 'CUB', 'CUW', 'FRO', 'FSM', 'GIB', 'GRL', 'GUM', 'IMN', 'INX', 'LIE', 'LUX', 'MAF', 'MCO', 'MHL', 'MNE', 'MNP', 'NCL', 'NRU', 'PLW', 'PRI', 'SMR', 'SRB', 'SSD', 'SXM', 'TCA', 'TLS', 'TUV', 'VIR', 'XKX'}

# %%
all = {'MNA', 'CHN', 'TJK', 'VEN', 'FSM', 'GRC', 'USA', 'NER', 'PYF', 'AFE', 'SGP', 'TSA', 'GIN', 'UZB', 'ARG', 'LIE', 'CHI', 'COL', 'AUT', 'DMA', 'BEN', 'ECA', 'ATG', 'AFG', 'UGA', 'WSM', 'AGO', 'SLV', 'PAN', 'UMC', 'IDX', 'PLW', 'SYC', 'PSS', 'KGZ', 'MMR', 'BLR', 'ISR', 'VNM', 'MEX', 'BGD', 'OSS', 'MCO', 'HKG', 'IRQ', 'GRL', 'CAF', 'LBN', 'SWZ', 'LVA', 'LBY', 'PAK', 'LMY', 'CHE', 'CYM', 'LKA', 'SSA', 'KOR', 'BRA', 'CSS', 'MUS', 'ARB', 'CEB', 'IND', 'BTN', 'NAC', 'SUR', 'DOM', 'ESP', 'SST', 'MOZ', 'TUV', 'FCS', 'TMN', 'BRN', 'ETH', 'ZWE', 'THA', 'TON', 'MRT', 'CMR', 'YEM', 'LBR', 'SSF', 'MAF', 'DJI', 'AUS', 'CHL', 'JPN', 'EAP', 'SAU', 'MNG', 'AND', 'FRA', 'NCL', 'SYR', 'BEL', 'NIC', 'VGB', 'NOR', 'EMU', 'TGO', 'BOL', 'VCT', 'OMN', 'SVN', 'BHR', 'LTU', 'NZL', 'PRK', 'IRL', 'TCD', 'GRD', 'NAM', 'DEU', 'SOM', 'MNE', 'GIB', 'ZMB', 'EAS', 'JAM', 'KHM', 'PST', 'SXM', 'UKR', 'MAR', 'TZA', 'COD', 'VUT', 'KNA', 'PSE', 'WLD', 'CUB', 'GMB', 'GTM', 'RWA', 'URY', 'TLA', 'INX', 'BMU', 'ASM', 'SVK', 'BDI', 'NLD', 'BFA', 'GUY', 'CUW', 'MEA', 'LUX', 'STP', 'PRY', 'HTI', 'HND', 'NPL', 'IMN', 'JOR', 'LSO', 'AZE', 'IBT', 'RUS', 'GNB', 'LDC', 'MIC', 'LCA', 'DNK', 'LMC', 'ZAF', 'QAT', 'EAR', 'FJI', 'ARM', 'TCA', 'CPV', 'GUM', 'LIC', 'SEN', 'BLZ', 'AFW', 'MDV', 'ITA', 'PRT', 'CYP', 'MHL', 'SRB', 'IBD', 'KAZ', 'MLT', 'EUU', 'HRV', 'KEN', 'LAC', 'IDN', 'OED', 'BRB', 'LAO', 'ERI', 'DZA', 'GHA', 'SLE', 'TUN', 'XKX', 'MDG', 'TKM', 'GAB', 'PHL', 'SDN', 'COG', 'HPC', 'GEO', 'CZE', 'IDA', 'TSS', 'ABW', 'GBR', 'CIV', 'VIR', 'TLS', 'BWA', 'CAN', 'PNG', 'HUN', 'PER', 'SWE', 'PRI', 'ISL', 'MLI', 'ARE', 'EGY', 'IDB', 'KIR', 'NRU', 'SLB', 'ALB', 'HIC', 'MYS', 'GNQ', 'POL', 'NGA', 'MAC', 'ROU', 'KWT', 'MNP', 'BHS', 'LTE', 'BGR', 'ECS', 'TTO', 'PRE', 'FIN', 'SMR', 'MWI', 'IRN', 'BIH', 'MKD', 'COM', 'TEC', 'TUR', 'SAS', 'TEA', 'CRI', 'LCN', 'FRO', 'EST', 'MDA', 'SSD', 'ECU'}

# %%
new = all - to_delate

# %%
print(new)
# Out:
# {'CRI', 'FRA', 'LAC', 'TON', 'SWZ', 'SWE', 'TSS', 'ZWE', 'TZA', 'CEB', 'SGP', 'SSA', 'BFA', 'OED', 'VEN', 'FIN', 'PYF', 'VNM', 'TUR', 'PNG', 'BWA', 'ECS', 'PRY', 'NAM', 'ABW', 'ITA', 'MAR', 'SAS', 'VUT', 'LKA', 'IND', 'CAN', 'GEO', 'MDG', 'AFG', 'COD', 'ALB', 'SUR', 'UKR', 'SVN', 'GIN', 'MYS', 'NAC', 'KHM', 'EST', 'WLD', 'MNA', 'DNK', 'PRT', 'MOZ', 'ISL', 'NZL', 'TCD', 'MIC', 'IBD', 'EAP', 'SOM', 'DMA', 'UMC', 'BDI', 'IBT', 'AUT', 'GRC', 'RWA', 'GAB', 'ISR', 'DOM', 'KEN', 'GNQ', 'IRN', 'EAS', 'ARM', 'BOL', 'CHL', 'MWI', 'LBN', 'CHE', 'ESP', 'ECA', 'PAK', 'MLI', 'UZB', 'PSS', 'MNG', 'MRT', 'VGB', 'IDX', 'NIC', 'AUS', 'BEL', 'GHA', 'GTM', 'CIV', 'QAT', 'CZE', 'TGO', 'BRB', 'ERI', 'DEU', 'SLV', 'CYM', 'ZMB', 'LVA', 'COL', 'GUY', 'SEN', 'BLR', 'STP', 'COG', 'PSE', 'HPC', 'MLT', 'POL', 'JOR', 'BHR', 'KAZ', 'ROU', 'PRK', 'NGA', 'MEX', 'TMN', 'SYC', 'KWT', 'TEA', 'CHN', 'GNB', 'GBR', 'LSO', 'TUN', 'HUN', 'AFW', 'FJI', 'SLB', 'VCT', 'CAF', 'JPN', 'GRD', 'ARE', 'LCN', 'HKG', 'TTO', 'THA', 'EG
# ...

# %%
df = wb.data.DataFrame('NV.IND.TOTL.ZS', new, time=range(1996, 2022))

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
df
# Out:
#             YR1996     YR1997     YR1998     YR1999     YR2000     YR2001  \
# economy
# ABW      14.987449  17.133844  17.510902  15.548314  13.177841  13.052754
# AFE      27.840686  26.906117  26.025392  25.876457  26.891046  26.841571
# AFG            NaN        NaN        NaN        NaN        NaN        NaN
# AFW      32.287256  31.582523  27.223316  28.172898  32.094777  28.071891
# AGO      67.820676  60.757741  55.157289  72.717372  72.122955  64.883812
# ALB      17.373841  18.109766  15.346838  16.536743  19.395689  21.735774
# ARB      43.029699  44.026162  39.595457  43.538157  49.542838  46.822910
# ARE      46.367002  45.428412  40.023532  42.020663  48.517012  49.676341
# ARG      26.592561  27.179151  26.712136  26.193630  25.990836  25.243434
# ARM            NaN        NaN        NaN        NaN        NaN        NaN
# ATG      12.247307  12.513128  12.658634  13.511606  13.890731  12.882524
# ...

# %%
x = {'AFG', 'ARM', 'BHR', 'CAF', 'CYM', 'DJI', 'DZA', 'FCS', 'GNQ', 'KWT', 'LBR', 'LBY', 'LCA', 'MDG', 'MDV', 'PRK', 'PYF', 'QAT', 'SLB', 'SLV', 'SOM', 'SST', 'STP', 'VGB', 'ZWE'} #HKG

# %%
new = new - x

# %%
df = wb.data.DataFrame('FP.CPI.TOTL.ZG', new, time=range(1996, 2022))

# %%
df
# Out:
#               YR1996       YR1997      YR1998      YR1999      YR2000  \
# economy
# ABW         3.225288     2.999948    1.869489    2.280372    4.044021
# AFE         9.706586    10.249599    7.495256    7.819865    8.601485
# AFW         4.914240     3.997142    4.471125    0.372266    2.530775
# AGO      4145.105982   219.176721  107.284822  248.195902  324.996872
# ALB        12.725478    33.180274   20.642859    0.389438    0.050018
# ARB         4.681306     3.601161    3.417319    2.669374    1.853790
# ARE              NaN          NaN         NaN         NaN         NaN
# ARG              NaN          NaN         NaN         NaN         NaN
# ATG              NaN          NaN         NaN    1.121288    0.771780
# AUS         2.615385     0.224888    0.860135    1.483129    4.457435
# AUT         1.860971     1.305979    0.922467    0.568994    2.344863
# AZE        19.794803     3.674348   -0.772698   -8.525170    1.805003
# ...

# %%
x = {'ARE', 'ARG', 'ATG', 'BMU', 'COG', 'COM', 'ERI', 'GIN', 'KIR', 'LBN', 'LSO', 'MOZ', 'NAM', 'NIC', 'OMN', 'PSS', 'SLE', 'TJK', 'TKM', 'UZB', 'VEN'}

# %%
new = new - x

# %%
df = wb.data.DataFrame('PA.NUS.PPPC.RF', new, time=range(1996, 2022))

# %%
df
# Out:
#            YR1996    YR1997    YR1998    YR1999    YR2000    YR2001    YR2002  \
# economy
# ABW      0.588019  0.599463  0.631874  0.636739  0.629031  0.649800  0.668278
# AFE           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# AFW           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# AGO      0.216844  0.201933  0.162254  0.148081  0.208483  0.191513  0.231701
# ALB      0.338871  0.263967  0.269361  0.297623  0.291786  0.298045  0.305729
# ARB           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# AUS      0.995012  1.022560  0.881077  0.812727  0.824016  0.712431  0.699294
# AUT      1.213694  1.050294  1.025725  0.984677  0.838128  0.826658  0.850824
# AZE      0.172888  0.200386  0.202153  0.191247  0.193727  0.186611  0.183435
# BDI      0.342868  0.383435  0.332535  0.299499  0.259200  0.250183  0.222029
# BEL      1.208614  1.045875  1.039761  0.992609  0.831196  0.799312  0.825770
# ...

# %%
x = {'OSS', 'SYR' }

# %%
new = new - x

# %%
economic_indicators_4 = ['BX.KLT.DINV.CD.WD', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'NV.AGR.TOTL.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD','NY.GDP.PCAP.PP.CD'] #były jeszcze takie gdzie wystarczyło kilka państw wywalić więc jakby co można dodać (z listy economic_indicators_3

# %%
print(new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 print(new)
#
# NameError: name 'new' is not defined

# %%
new = {'CRI', 'FRA', 'NGA', 'MEX', 'LAC', 'TMN', 'SYC', 'TEA', 'TON', 'SWZ', 'SWE', 'CHN', 'GNB', 'GBR', 'TSS', 'TZA', 'CEB', 'TUN', 'HUN', 'AFW', 'SGP', 'FJI', 'SSA', 'BFA', 'OED', 'FIN', 'VCT', 'VNM', 'TUR', 'PNG', 'JPN', 'GRD', 'LCN', 'BWA', 'ECS', 'PRY', 'ABW', 'ITA', 'MAR', 'SAS', 'TTO', 'VUT', 'LKA', 'IND', 'CAN', 'GEO', 'THA', 'EGY', 'COD', 'CSS', 'BLZ', 'ALB', 'SUR', 'UKR', 'SVN', 'MYS', 'CPV', 'TEC', 'NAC', 'KHM', 'MUS', 'EST', 'WLD', 'HRV', 'NLD', 'MNA', 'DNK', 'ZAF', 'PRT', 'AFE', 'ISL', 'HIC', 'ETH', 'NER', 'GMB', 'NZL', 'AZE', 'SAU', 'TCD', 'MIC', 'KOR', 'TSA', 'IBD', 'EAP', 'BEN', 'DMA', 'UMC', 'CMR', 'BDI', 'WSM', 'IBT', 'MEA', 'IRL', 'MDA', 'AUT', 'GRC', 'RWA', 'PST', 'GAB', 'LAO', 'ISR', 'DOM', 'KEN', 'LMC', 'EAR', 'IRN', 'PER', 'EAS', 'BOL', 'CHL', 'MWI', 'UGA', 'HTI', 'CHE', 'ESP', 'NOR', 'ECA', 'PAK', 'MLI', 'ECU', 'USA', 'KGZ', 'SVK', 'IRQ', 'MKD', 'LTE', 'BRA', 'MNG', 'BRN', 'KNA', 'SSF', 'NPL', 'MRT', 'LDC', 'EMU', 'BGD', 'HND', 'IDX', 'AUS', 'BEL', 'GHA', 'LIC', 'GTM', 'IDN', 'IDB', 'CIV', 'CZE', 'TGO', 'BRB', 'LTU', 'CYP', 'DEU', 'YEM', 'SDN', 'ZMB', 'LVA', 'COL', 'GUY', 'JAM', 'AGO', 'BHS', 'SEN', 'BGR', 'BLR', 'PAN', 'URY', 'IDA', 'PSE', 'HPC', 'MLT', 'TLA', 'POL', 'PRE', 'JOR', 'PHL', 'ARB', 'LMY', 'KAZ', 'RUS', 'ROU', 'EUU'}

# %% [markdown]
# ## DLA POWYŻSZYCH EKONOMICZNYCH (4) państwa to new

# %% [markdown]
# teraz kolejne wskaźniki trzeba popróbować na tych państwach i ewentlalnie zmniejszać

# %%
health_indicators_2 = ['SP.ADO.TFRT', 'SP.ADO.TFRT', 'SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SH.IMM.IDPT', 'SP.DYN.LE00.FE.IN', 'SP.DYN.LE00.IN', 'SP.DYN.LE00.MA.IN', 'SH.IMM.MEAS', 'SP.POP.DPND', 'SP.POP.TOTL.FE.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.0014.TO.ZS', 'SM.POP.NETM', 'SH.DYN.NMRT', 'SP.DYN.IMRT.IN', 'SH.DYN.MORT', 'SP.POP.1564.TO.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SM.POP.REFG']

# %%
df = wb.data.DataFrame('SM.POP.REFG', new, time=range(1996, 2022))

# %%
df
# Out:
#              YR1996      YR1997      YR1998      YR1999      YR2000  \
# economy
# ABW             NaN         NaN         NaN         NaN         NaN
# AFE       2664044.0   2231241.0   2138848.0   2305181.0   2444941.0
# AFW       1467808.0   1048344.0    999433.0   1011187.0    968325.0
# AGO          9379.0      9361.0     10603.0     13068.0     12086.0
# ALB          4927.0        34.0     22334.0      3932.0       521.0
# ARB       4219795.0   4243118.0   4373377.0   4487615.0   4639911.0
# AUS         67298.0     66056.0     69714.0     64879.0     60219.0
# AUT         89116.0     84394.0     80294.0     82076.0     15493.0
# AZE        233693.0    233716.0    221636.0    221642.0       280.0
# BDI         20734.0     22027.0     25092.0     22107.0     27133.0
# BEL         36060.0     36060.0     15501.0     16747.0     18821.0
# BEN          5961.0      2914.0      2898.0      3652.0      4290.0
# BFA         28381.0      1799.0       562.0       672.0       692.0
# ...

# %%
health_indicators_3 = ['SP.ADO.TFRT', 'SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN','SP.DYN.TFRT.IN', 'SP.DYN.LE00.FE.IN', 'SP.DYN.LE00.IN', 'SP.DYN.LE00.MA.IN', 'SP.POP.DPND', 'SP.POP.TOTL.FE.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.0014.TO.ZS', 'SM.POP.NETM', 'SH.DYN.NMRT', 'SP.POP.1564.TO.ZS', 'SP.POP.GROW', 'SP.POP.TOTL',] # poniżej są te gdzie wystarczy usunąć ABW

# %%
#SH.IMM.IDPT -> ABW
#SH.IMM.MEAS -> ABW
#SH.DYN.NMRT -> ABW
#SP.DYN.IMRT.IN -> ABW
#SH.DYN.MORT -> ABW

# %%
socjo_demogra_indicators_3 = ['SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SM.POP.NETM', 'SP.POP.0014.TO.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.TOTL.FE.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SP.URB.TOTL.IN.ZS', 'SP.URB.TOTL', 'SP.URB.TOTL.IN.ZS',  'SP.URB.TOTL.IN.ZS'] # ponizej jedno wystarczy usunąć ABW

# %%
#SL.UEM.TOTL.ZS -> ABW

# %%
df = wb.data.DataFrame('SP.URB.TOTL.IN.ZS', new, time=range(1996, 2022))

# %%
df
# Out:
#              YR1996      YR1997      YR1998      YR1999      YR2000  \
# economy
# ABW       48.356000   47.946000   47.536000   47.127000   46.717000
# AFE       27.624897   27.911072   28.203375   28.489868   28.772780
# AFW       33.474074   33.927806   34.393293   34.863518   35.337049
# AGO       45.346000   46.525000   47.710000   48.897000   50.087000
# ALB       39.473000   40.035000   40.601000   41.169000   41.741000
# ARB       52.091924   52.316175   52.562001   52.810526   53.055997
# AUS       84.767000   84.636000   84.503000   84.370000   84.235000
# AUT       61.320000   61.045000   60.768000   60.491000   60.213000
# AZE       51.896000   51.588000   51.278000   51.185000   51.386000
# BDI        7.412000    7.618000    7.830000    8.036000    8.246000
# BEL       96.851000   96.924000   96.996000   97.065000   97.129000
# BEN       37.071000   37.385000   37.699000   38.015000   38.333000
# BFA       15.407000   15.875000   16.510000   17.166000   17.844000
# ...

# %% [markdown]
# ## KOŃCOWE JESZCZE DO PRZEPATRZENIA (181 państw) (pojedyncze braki raczej można średnią itp):

# %%
socjo_demogra_indicators = ['SP.DYN.CDRT.IN', 'SP.DYN.TFRT.IN', 'SM.POP.NETM', 'SP.POP.0014.TO.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.TOTL.FE.ZS', 'SP.POP.GROW', 'SP.POP.TOTL', 'SP.URB.TOTL.IN.ZS', 'SP.URB.TOTL', 'SP.URB.TOTL.IN.ZS',  'SP.URB.TOTL.IN.ZS']
health_indicators = ['SP.ADO.TFRT', 'SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN','SP.DYN.TFRT.IN', 'SP.DYN.LE00.FE.IN', 'SP.DYN.LE00.IN', 'SP.DYN.LE00.MA.IN', 'SP.POP.DPND', 'SP.POP.TOTL.FE.ZS', 'SP.POP.65UP.TO.ZS', 'SP.POP.0014.TO.ZS', 'SM.POP.NETM', 'SH.DYN.NMRT', 'SP.POP.1564.TO.ZS', 'SP.POP.GROW', 'SP.POP.TOTL',]
economic_indicators = ['BX.KLT.DINV.CD.WD', 'NV.IND.TOTL.ZS', 'FP.CPI.TOTL.ZG', 'NV.AGR.TOTL.ZS', 'NY.GDP.MKTP.CD', 'NY.GDP.PCAP.CD','NY.GDP.PCAP.PP.CD']

# %%
countrys = {'EAP', 'BEN', 'SUR', 'EAR', 'TEC', 'JPN', 'CHN', 'SAU', 'LDC', 'MEX', 'IRQ', 'CYP', 'TSS', 'IND', 'LTE', 'IDN', 'MUS', 'NGA', 'BRA', 'TGO', 'HIC', 'SWE', 'CSS', 'PAN', 'COD', 'THA', 'ITA', 'PRY', 'TUR', 'MEA', 'ROU', 'BGD', 'IRN', 'TTO', 'BLR', 'JAM', 'GNB', 'DOM', 'AZE', 'ABW', 'GUY', 'TZA', 'COL', 'LVA', 'TLA', 'TEA', 'UMC', 'PAK', 'ESP', 'EMU', 'RUS', 'SAS', 'CIV', 'GHA', 'GRC', 'CRI', 'SYC', 'MKD', 'CZE', 'BRB', 'SGP', 'SSA', 'PER', 'CMR', 'MIC', 'HND', 'CHE', 'BLZ', 'AGO', 'GAB', 'CAN', 'HRV', 'ECU', 'BWA', 'CEB', 'GRD', 'FJI', 'VNM', 'PST', 'ETH', 'CPV', 'MYS', 'USA', 'UGA', 'VCT', 'AFE', 'BFA', 'SDN', 'MDA', 'MNA', 'LMY', 'LKA', 'MAR', 'ISR', 'PHL', 'MNG', 'GBR', 'BGR', 'IDA', 'BEL', 'HPC', 'BOL', 'IBD', 'SVN', 'VUT', 'TON', 'SEN', 'DEU', 'FIN', 'NLD', 'EAS', 'TMN', 'LAC', 'RWA', 'PSE', 'MRT', 'FRA', 'BDI', 'NOR', 'OED', 'GTM', 'GMB', 'WSM', 'PRE', 'ECS', 'CHL', 'YEM', 'NAC', 'JOR', 'DNK', 'EUU', 'ALB', 'NPL', 'IRL', 'AFW', 'MLT', 'ECA', 'AUT', 'POL', 'KOR', 'MLI', 'WLD', 'KNA', 'NER', 'ZMB', 'DMA', 'LAO', 'SVK', 'ISL', 'LCN', 'PNG', 'KAZ', 'TUN', 'KEN', 'URY', 'KGZ', 'AUS', 'PRT', 'ARB', 'LMC', 'EST', 'IDX', 'EGY', 'KHM', 'LTU', 'GEO', 'BHS', 'ZAF', 'UKR', 'MWI', 'SSF', 'IBT', 'LIC', 'HUN', 'NZL', 'TCD', 'BRN', 'TSA', 'IDB', 'HTI', 'SWZ'}

# %%
len(countrys)
# Out:
# 181
